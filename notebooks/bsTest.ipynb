# %%
from bs4 import BeautifulSoup as bs

# %%
html_doc = """
<html><head><title>The Dormouse's story</title></head>
<body>
<p class="title"><b>The Dormouse's story</b></p>

<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>

<p class="story">...</p>
"""

# %%
soup=bs(html_doc, "html.parser")

# %%
print soup
# Out:
# <html><head><title>The Dormouse's story</title></head>
# <body>
# <p class="title"><b>The Dormouse's story</b></p>
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>
# <p class="story">...</p>
# </body></html>

# %%
print soup.prettify()
# Out:
# <html>
#  <head>
#   <title>
#    The Dormouse's story
#   </title>
#  </head>
#  <body>
#   <p class="title">
#    <b>
#     The Dormouse's story
#    </b>
#   </p>
#   <p class="story">
#    Once upon a time there were three little sisters; and their names were
#    <a class="sister" href="http://example.com/elsie" id="link1">
#     Elsie
#    </a>
#    ,
#    <a class="sister" href="http://example.com/lacie" id="link2">
#     Lacie
#    </a>
#    and
#    <a class="sister" href="http://example.com/tillie" id="link3">
#     Tillie
#    </a>
#    ;
# and they lived at the bottom of a well.
#   </p>
#   <p class="story">
#    ...
#   </p>
#  </body>
# </html>

# %%
text=soup.get_text()
print text
# Out:
# The Dormouse's story
#
# The Dormouse's story
# Once upon a time there were three little sisters; and their names were
# Elsie,
# Lacie and
# Tillie;
# and they lived at the bottom of a well.
# ...

# %%
print type(text)
# Out:
# <type 'unicode'>

# %%
def wordCount(word, passage):
    wc=0
    for w in passage:
        if w==word:
            wc+=1
    return wc
print wordCount("story", text)
# Out:
# 0

# %%
for w in text.split():
    print w
# Out:
# The
# Dormouse's
# story
# The
# Dormouse's
# story
# Once
# upon
# a
# time
# there
# were
# three
# little
# sisters;
# and
# their
# names
# were
# Elsie,
# Lacie
# and
# Tillie;
# and
# they
# lived
# at
# the
# bottom
# of
# a
# well.
# ...

# %%
import xml.etree.ElementTree as ET
tree = ET.parse('http://feeds.bbci.co.uk/news/world/rss.xml')
print tree
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-16-06438fe359fe> in <module>()
#       1 import xml.etree.ElementTree as ET
# ----> 2 tree = ET.parse('http://feeds.bbci.co.uk/news/world/rss.xml')
#       3 print tree
#
# /opt/anaconda2/lib/python2.7/xml/etree/ElementTree.pyc in parse(source, parser)
#    1180 def parse(source, parser=None):
#    1181     tree = ElementTree()
# -> 1182     tree.parse(source, parser)
#    1183     return tree
#    1184
#
# /opt/anaconda2/lib/python2.7/xml/etree/ElementTree.pyc in parse(self, source, parser)
#     645         close_source = False
#     646         if not hasattr(source, "read"):
# --> 647             source = open(source, "rb")
#     648             close_source = True
#     649         try:
#
# IOError: [Errno 2] No such file or directory: 'http://feeds.bbci.co.uk/news/world/rss.xml'

# %%
bbcFeed="""<?xml version="1.0" encoding="UTF-8"?>
<?xml-stylesheet title="XSL_formatting" type="text/xsl" href="/shared/bsp/xsl/rss/nolsol.xsl"?>
<rss xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:content="http://purl.org/rss/1.0/modules/content/" xmlns:atom="http://www.w3.org/2005/Atom" version="2.0" xmlns:media="http://search.yahoo.com/mrss/">
    <channel>
        <title><![CDATA[BBC News - World]]></title>
        <description><![CDATA[BBC News - World]]></description>
        <link>http://www.bbc.co.uk/news/</link>
        
            <url>http://news.bbcimg.co.uk/nol/shared/img/bbc_news_120x60.gif</url>
            <title>BBC News - World</title>
            <link>http://www.bbc.co.uk/news/</link>
        
        <generator>RSS for Node</generator>
        <lastBuildDate>Tue, 20 Sep 2016 20:44:56 GMT</lastBuildDate>
        <copyright><![CDATA[Copyright: (C) British Broadcasting Corporation, see http://news.bbc.co.uk/2/hi/help/rss/4498287.stm for terms and conditions of reuse.]]></copyright>
        <language><![CDATA[en-gb]]></language>
        <ttl>15</ttl>
        <item>
            <title><![CDATA[Syria conflict: UN suspends all aid after convoy hit]]></title>
            <description><![CDATA[The UN suspends all aid convoys in Syria after an attack on its lorries near Aleppo, as Russia and Syria deny any involvement.]]></description>
            <link>http://www.bbc.co.uk/news/world-middle-east-37417898</link>
            <guid isPermaLink="true">http://www.bbc.co.uk/news/world-middle-east-37417898</guid>
            <pubDate>Tue, 20 Sep 2016 19:06:14 GMT</pubDate>
            <media:thumbnail width="1000" height="562" url="http://c.files.bbci.co.uk/15C35/production/_91314198_035419658.jpg"/>
        </item>
        <item>
            <title><![CDATA[Angelina Jolie to divorce Brad Pitt]]></title>
            <description><![CDATA[Angelina Jolie has filed for divorce from Brad Pitt "for the health of the family" and citing irreconcilable differences, says her lawyer.]]></description>
            <link>http://www.bbc.co.uk/news/entertainment-arts-37422843</link>
            <guid isPermaLink="true">http://www.bbc.co.uk/news
GMT</pubDate>
            <media:thumbnail width="976" height="549" url="http://c.files.bbci.co.uk/E8C3/production/_90978595_aba39079-417f-448f-9855-242774e42955.jpg"/>
        </item>
        <item>
            <title><![CDATA[Together again]]></title>
            <description><![CDATA[Lyse Doucet is reunited with a Syrian family she met in Damascus in 2014. The youngest tells Doucet what's changed since her family moved to Canada.]]></description>
            <link>http://www.bbc.co.uk/news/world-us-canada-37412117</link>
            <guid isPermaLink="true">http://www.bbc.co.uk/news/world-us-canada-37412117</guid>
            <pubDate>Tue, 20 Sep 2016 00:00:14 GMT</pubDate>
            <media:thumbnail width="1920" height="1080" url="http://c.files.bbci.co.uk/12D5F/production/_91315177_de54.jpg"/>
        </item>
        <item>
            <title><![CDATA[Old enough to vote]]></title>
            <description><![CDATA[Some 45,000 people have turned 16 in the months since Austria's botched presidential election. Will they prevent far-right candidate Norbert Hofer winning the re-run vote?]]></description>
            <link>http://www.bbc.co.uk/news/world-europe-37405447</link>
            <guid isPermaLink="true">http://www.bbc.co.uk/news/world-europe-37405447</guid>
            <pubDate>Mon, 19 Sep 2016 23:04:10 GMT</pubDate>
            <media:thumbnail width="976" height="549" url="http://c.files.bbci.co.uk/10D7D/production/_91298986_austrians.gif"/>
        </item>
        <item>
            <title><![CDATA[Bears with keyboards]]></title>
            <description><![CDATA[Olympic stars are the latest targets of computer hackers believed to have high-level backing in Russia, the BBC's Andrei Soshnikov reports.]]></description>
            <link>http://www.bbc.co.uk/news/world-europe-37409456</link>
            <guid isPermaLink="true">http://www.bbc.co.uk/news/world-europe-37409456</guid>
            <pubDate>Tue, 20 Sep 2016 00:42:55 GMT</pubDate>
            <media:thumbnail width="976" height="549" url="http://c.files.bbci.co.uk/14803/production/_91217938_thinkstockphotos-530353537.jpg"/>
        </item>
        <item>
            <title><![CDATA[Be-all-and-end-all?]]></title>
            <description><![CDATA[Chinese social media users have been expressing doubts about the institution of marriage, prompted by a post on a popular Sina Weibo account about a New York Times report.]]></description>
            <link>http://www.bbc.co.uk/news/world-asia-china-37411681</link>
            <guid isPermaLink="true">http://www.bbc.co.uk/news/world-asia-china-37411681</guid>
            <pubDate>Mon, 19 Sep 2016 23:55:30 GMT</pubDate>
            <media:thumbnail width="976" height="549" url="http://c.files.bbci.co.uk/17340/production/_91304059_chinam.jpg"/>
        </item>
    </channel>
</rss>"""

# %%
bbcText=bs(bbcFeed, "html.parser")

# %%
print bbcText.prettify()
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <?xml-stylesheet title="XSL_formatting" type="text/xsl" href="/shared/bsp/xsl/rss/nolsol.xsl"?>
# <rss version="2.0" xmlns:atom="http://www.w3.org/2005/Atom" xmlns:content="http://purl.org/rss/1.0/modules/content/" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:media="http://search.yahoo.com/mrss/">
#  <channel>
#   <title>
#    <![CDATA[BBC News - World]]>
#   </title>
#   <description>
#    <![CDATA[BBC News - World]]>
#   </description>
#   <link>
#    http://www.bbc.co.uk/news/
#   </link>
#
#    <url>
#     http://news.bbcimg.co.uk/nol/shared/img/bbc_news_120x60.gif
#    </url>
#    <title>
#     BBC News - World
#    </title>
#    <link>
#     http://www.bbc.co.uk/news/
#    </link>
#
#   <generator>
#    RSS for Node
#   </generator>
#   <lastbuilddate>
#    Tue, 20 Sep 2016 20:44:56 GMT
#   </lastbuilddate>
#   <copyright>
# ...

# %%
items=bbcText("item")

# %%
key="UN"       #Keyword
relArticles=[]    #List of articles related to keyword
for item in items:
    if key in item.get_text().split():
        relArticles.append(item)

# %%
relArticles
# Out:
# [<item>\n<title><![CDATA[Syria conflict: UN suspends all aid after convoy hit]]></title>\n<description><![CDATA[The UN suspends all aid convoys in Syria after an attack on its lorries near Aleppo, as Russia and Syria deny any involvement.]]></description>\n<link>http://www.bbc.co.uk/news/world-middle-east-37417898</link>\n<guid ispermalink="true">http://www.bbc.co.uk/news/world-middle-east-37417898</guid>\n<pubdate>Tue, 20 Sep 2016 19:06:14 GMT</pubdate>\n<media:thumbnail height="562" url="http://c.files.bbci.co.uk/15C35/production/_91314198_035419658.jpg" width="1000"></media:thumbnail>\n</item>,
# ...

# %%
# Out:
# True
