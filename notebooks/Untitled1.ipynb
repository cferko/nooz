# %%
import pandas as pd
my_frame = pd.read_csv("/home/cferko/nooz/scripts/2016-09-26_fixed.csv", sep="|")

# %%
my_frame.columns = range(len(my_frame.columns))

# %%
out = my_frame[np.in1d("oil"), my_frame['The reason oil companies have gone bankrupt over the past few years is not due to historically low oil and natural gas prices as stated in this article. Here is a long term inflation adjusted price chart: (Click to enlarge) Does the current price look historically low on an inflation adjusted basis? Here is the chart not adjusted for inflation.  (Click to enlarge) Natural Gas prices are closer to the lower end of the price range. Below is the inflation adjusted long term natural gas price. (Click to enlarge)However  for as far']]
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-3-9fb2d2c89743> in <module>()
# ----> 1 out = my_frame[np.in1d("oil"), my_frame['The reason oil companies have gone bankrupt over the past few years is not due to historically low oil and natural gas prices as stated in this article. Here is a long term inflation adjusted price chart: (Click to enlarge) Does the current price look historically low on an inflation adjusted basis? Here is the chart not adjusted for inflation.  (Click to enlarge) Natural Gas prices are closer to the lower end of the price range. Below is the inflation adjusted long term natural gas price. (Click to enlarge)However  for as far']]
#
# NameError: name 'np' is not defined

# %%
my_frame[:5]
# Out:
#                             0  \
# 0  2016-09-26 10:28:19.255548
# 1  2016-09-26 10:28:19.255606
# 2  2016-09-26 10:28:19.255656
# 3  2016-09-26 10:28:19.255709
# 4  2016-09-26 10:28:19.255757
#
#                                                    1  \
# 0                                          Oil Rises
# 1    Niger Delta Avengers Blow Up Oil Pipeline Again
# 2  Why Oil Prices Will Rise More And Sooner Than ...
# 3            Only An OPEC Miracle Can Save Venezuela
# 4             What If The Oil Rebound Never Happens?
#
#                                                    2  \
# 0   Skepticism Too  As OPEC Meets To Talk Output ...
# 1  The Niger Delta Avengers announced yesterday t...
# 2  As the September 26 to 28 informal meeting of ...
# 3  Oil producers could see a $10 to $15 spike in ...
# 4  Oil prices are hovering in the mid-$40s per ba...
#
#                                                    3
# 0  http://oilprice.com/Energy/Oil-Prices/Oil-Rise...
# ...

# %%
import numpy as np
out = my_frame[np.in1d("oil", my_frame[2].values)]
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-8-1cd42ad84e6c> in <module>()
#       1 import numpy as np
# ----> 2 out = my_frame[np.in1d("oil", my_frame[2].values)]
#
# /opt/anaconda2/lib/python2.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1989         if isinstance(key, (Series, np.ndarray, Index, list)):
#    1990             # either boolean or fancy integer index
# -> 1991             return self._getitem_array(key)
#    1992         elif isinstance(key, DataFrame):
#    1993             return self._getitem_frame(key)
#
# /opt/anaconda2/lib/python2.7/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2026             elif len(key) != len(self.index):
#    2027                 raise ValueError('Item wrong length %d instead of %d.' %
# -> 2028                                  (len(key), len(self.index)))
#    2029             # check_bool_indexer will throw exception if Series key cannot
# ...

# %%
np.in1d("oil", my_frame[2].values)
# Out:
# array([False], dtype=bool)

# %%
my_frame[my_frame[2].apply(lambda row: "oil" in row)]
# Out:
#                               0  \
# 0    2016-09-26 10:28:19.255548
# 2    2016-09-26 10:28:19.255656
# 3    2016-09-26 10:28:19.255709
# 4    2016-09-26 10:28:19.255757
# 5    2016-09-26 10:28:19.255823
# 9    2016-09-26 10:28:19.256055
# 10   2016-09-26 10:28:19.256110
# 12   2016-09-26 10:28:19.256232
# 13   2016-09-26 10:28:19.256293
# 15   2016-09-26 10:28:19.337880
# 27   2016-09-26 10:28:19.473363
# 29   2016-09-26 10:28:19.473561
# 31   2016-09-26 10:28:19.473743
# 32   2016-09-26 10:28:19.473839
# 33   2016-09-26 10:28:19.473975
# 35   2016-09-26 10:28:19.474187
# 38   2016-09-26 10:28:19.474508
# 39   2016-09-26 10:28:19.474611
# 40   2016-09-26 10:28:19.474717
# 43   2016-09-26 10:28:19.475063
# 49   2016-09-26 10:28:19.475805
# 56   2016-09-26 10:28:19.476746
# 59   2016-09-26 10:28:19.477162
# 60   2016-09-26 10:28:19.477294
# 61   2016-09-26 10:28:19.477430
# 66   2016-09-26 10:28:19.478255
# 71   2016-09-26 10:28:19.574996
# 74   2016-09-26 10:28:19.575504
# ...

# %%
my_frame[2].apply(lambda row: "oil" in row)
# Out:
# 0       True
# 1      False
# 2       True
# 3       True
# 4       True
# 5       True
# 6      False
# 7      False
# 8      False
# 9       True
# 10      True
# 11     False
# 12      True
# 13      True
# 14     False
# 15      True
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27      True
# 28     False
# 29      True
#        ...
# 584    False
# 585     True
# 586     True
# 587     True
# 588     True
# 589     True
# 590     True
# 591     True
# 592     True
# 593    False
# 594     True
# 595     True
# 596     True
# 597     True
# 598     True
# 599     True
# 600    False
# 601     True
# 602     True
# 603     True
# 604     True
# 605     True
# 606     True
# 607     True
# 608     True
# 609    False
# 610     True
# 611     True
# 612     True
# 613     True
# Name: 2, dtype: bool

# %%
test=[1.5]*1 + [4]*3 + [6]*6 + [8]*7 + [10]
print test
# Out:
# [1.5, 4, 4, 4, 6, 6, 6, 6, 6, 6, 8, 8, 8, 8, 8, 8, 8, 10]

# %%
print np.mean(test), np.std(test)
# Out:
# 6.41666666667 2.01556443707
